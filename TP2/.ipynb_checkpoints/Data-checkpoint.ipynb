# %%
# Imports

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Table

data = pd.read_csv("data.csv");
milis = np.zeros(43);
Mbps = np.zeros(43);
for it in range(43):
    milis[it] = round(data.iat[it,1]/10000)/100;
    Mbps[it] = round(data.iat[it,2]/10000)/100;
data.insert(3, "Latency (ms)", milis);
data.insert(4, "Throughput (Mbps)", Mbps);
display(data);
# Out:
#     Data (bytes)  Latency (ns)  Troughput (bps)  Latency (ms)  \
# 0              1        306589          26093.6          0.31
# 1            100        289387        2764460.0          0.29
# 2            200        285229        5609530.0          0.29
# 3            300        289778        8282200.0          0.29
# 4            400        286497       11169400.0          0.29
# 5            500        284480       14060700.0          0.28
# 6            600        288396       16643800.0          0.29
# 7            700        302995       18482200.0          0.30
# 8            800        288939       22150000.0          0.29
# 9            900        295639       24354000.0          0.30
# 10          1000        287907       27786800.0          0.29
# 11          1024        288365       28408400.0          0.29
# 12          2048        302027       54246800.0          0.30
# 13          3072        309771       79336000.0          0.31
# 14          4096        310226      105626000.0          0.31
# 15          5120        323691      126540000.0          0.32
# 16          6144        342335      143579000.0          0.34
# 17          7168        337353      169982000.0          0.34
# 18          8192        360046      182021000.0          0.36
# 19          9216        355928      207143000.0          0.36
# 20         10240        367077      223168000.0          0.37
# 21         11264        381948      235927000.0          0.38
# 22         12288        389644      252292000.0          0.39
# 23         13312        408213      260883000.0          0.41
# 24         14336        395309      290122000.0          0.40
# 25         15360        421663      291418000.0          0.42
# 26         16384        412556      317707000.0          0.41
# 27         17408        417934      333220000.0          0.42
# 28         18432        438650      336159000.0          0.44
# 29         19456        448777      346827000.0          0.45
# 30         20480        459890      356259000.0          0.46
# 31         21504        454334      378647000.0          0.45
# 32         22528        489143      368448000.0          0.49
# 33         23552        477072      394942000.0          0.48
# 34         24576        502186      391504000.0          0.50
# 35         25600        523214      391427000.0          0.52
# 36         26624        496365      429104000.0          0.50
# 37         27648        524132      422001000.0          0.52
# 38         28672        530758      432167000.0          0.53
# 39         29696        519891      456957000.0          0.52
# 40         30720        595074      412991000.0          0.60
# 41         31744        550962      460925000.0          0.55
# 42         32768        557821      469943000.0          0.56
#
#     Throughput (Mbps)
# 0                0.03
# 1                2.76
# 2                5.61
# 3                8.28
# 4               11.17
# 5               14.06
# 6               16.64
# 7               18.48
# 8               22.15
# 9               24.35
# 10              27.79
# 11              28.41
# 12              54.25
# 13              79.34
# 14             105.63
# 15             126.54
# 16             143.58
# 17             169.98
# 18             182.02
# 19             207.14
# 20             223.17
# 21             235.93
# 22             252.29
# 23             260.88
# 24             290.12
# 25             291.42
# 26             317.71
# 27             333.22
# 28             336.16
# 29             346.83
# 30             356.26
# 31             378.65
# 32             368.45
# 33             394.94
# 34             391.50
# 35             391.43
# 36             429.10
# 37             422.00
# 38             432.17
# 39             456.96
# 40             412.99
# 41             460.92
# 42             469.94

# %%
# Plot

rawValues = np.transpose(data.values);

figure, axis = plt.subplots(2);
figure.suptitle("Latency and throughput");
axis[0].set_ylabel("ms");
axis[0].plot(rawValues[0], rawValues[3]);
axis[1].set_xlabel("bytes");
axis[1].set_ylabel("Mbps");
axis[1].plot(rawValues[0], rawValues[4]);
