# %%
# Imports

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Table

data = pd.read_csv("data.csv");
milis = np.zeros(43);
Mbps = np.zeros(43);
for it in range(43):
    milis[it] = round(data.iat[it,1]/10000)/100;
    Mbps[it] = round(data.iat[it,2]/10000)/100;
data.insert(3, "Latency (ms)", milis);
data.insert(4, "Throughput (Mbps)", Mbps);
display(data);
# Out:
#     Data (bytes)  Latency (ns)  Troughput (bps)  Latency (ms)  \
# 0              1       5792616          1381.07          5.79
# 1            100       6551430        122111.00          6.55
# 2            200       6859796        233243.00          6.86
# 3            300       8743463        274491.00          8.74
# 4            400       8585506        372721.00          8.59
# 5            500       7189078        556400.00          7.19
# 6            600       7276019        659701.00          7.28
# 7            700       6722453        833029.00          6.72
# 8            800       6492358        985774.00          6.49
# 9            900       6498229       1107990.00          6.50
# 10          1000       7254694       1102730.00          7.25
# 11          1024       7572208       1081850.00          7.57
# 12          2048      12469012       1313980.00         12.47
# 13          3072      15428099       1592940.00         15.43
# 14          4096       8254576       3969680.00          8.25
# 15          5120      10246160       3997600.00         10.25
# 16          6144      26356699       1864880.00         26.36
# 17          7168      11720043       4892810.00         11.72
# 18          8192      13109251       4999220.00         13.11
# 19          9216      17349724       4249520.00         17.35
# 20         10240      13174109       6218260.00         13.17
# 21         11264      15877455       5675470.00         15.88
# 22         12288      20727287       4742730.00         20.73
# 23         13312      18011375       5912710.00         18.01
# 24         14336      18626465       6157260.00         18.63
# 25         15360      22435837       5476950.00         22.44
# 26         16384      50523767       2594260.00         50.52
# 27         17408      24842715       5605830.00         24.84
# 28         18432      62427092       2362050.00         62.43
# 29         19456      38408416       4052450.00         38.41
# 30         20480      30609176       5352640.00         30.61
# 31         21504      25760929       6678020.00         25.76
# 32         22528      35141957       5128460.00         35.14
# 33         23552      23234502       8109320.00         23.23
# 34         24576      35151365       5593180.00         35.15
# 35         25600      36189636       5659080.00         36.19
# 36         26624      33578274       6343150.00         33.58
# 37         27648      40047620       5523020.00         40.05
# 38         28672      31245446       7341100.00         31.25
# 39         29696      49187912       4829800.00         49.19
# 40         30720      31003257       7926910.00         31.00
# 41         31744      45573246       5572390.00         45.57
# 42         32768      52629794       4980900.00         52.63
#
#     Throughput (Mbps)
# 0                0.00
# 1                0.12
# 2                0.23
# 3                0.27
# 4                0.37
# 5                0.56
# 6                0.66
# 7                0.83
# 8                0.99
# 9                1.11
# 10               1.10
# 11               1.08
# 12               1.31
# 13               1.59
# 14               3.97
# 15               4.00
# 16               1.86
# 17               4.89
# 18               5.00
# 19               4.25
# 20               6.22
# 21               5.68
# 22               4.74
# 23               5.91
# 24               6.16
# 25               5.48
# 26               2.59
# 27               5.61
# 28               2.36
# 29               4.05
# 30               5.35
# 31               6.68
# 32               5.13
# 33               8.11
# 34               5.59
# 35               5.66
# 36               6.34
# 37               5.52
# 38               7.34
# 39               4.83
# 40               7.93
# 41               5.57
# 42               4.98

# %%
# Plot

rawValues = np.transpose(data.values);

figure, axis = plt.subplots(2);
figure.suptitle("Latency (Mbps) and throughput (ms)");
axis[0].plot(rawValues[0], rawValues[3]);
axis[1].plot(rawValues[0], rawValues[4]);

# %%
# Filter

milis = np.zeros(43);
Mbps = np.zeros(43);
milis[0] = data.iat[0,3];
Mbps[0] = data.iat[0,4];
for it in range(42):
    milis[it+1] = (7*milis[it]+data.iat[it+1,3])/8;
    Mbps[it+1] = (7*Mbps[it]+data.iat[it+1,4])/8;
data.insert(5, "Filtered latency (ms)", milis);
data.insert(6, "Filtered throughput (Mbps)", Mbps);
display(data);
# Out:
#     Data (bytes)  Latency (ns)  Troughput (bps)  Latency (ms)  \
# 0              1       5792616          1381.07          5.79
# 1            100       6551430        122111.00          6.55
# 2            200       6859796        233243.00          6.86
# 3            300       8743463        274491.00          8.74
# 4            400       8585506        372721.00          8.59
# 5            500       7189078        556400.00          7.19
# 6            600       7276019        659701.00          7.28
# 7            700       6722453        833029.00          6.72
# 8            800       6492358        985774.00          6.49
# 9            900       6498229       1107990.00          6.50
# 10          1000       7254694       1102730.00          7.25
# 11          1024       7572208       1081850.00          7.57
# 12          2048      12469012       1313980.00         12.47
# 13          3072      15428099       1592940.00         15.43
# 14          4096       8254576       3969680.00          8.25
# 15          5120      10246160       3997600.00         10.25
# 16          6144      26356699       1864880.00         26.36
# 17          7168      11720043       4892810.00         11.72
# 18          8192      13109251       4999220.00         13.11
# 19          9216      17349724       4249520.00         17.35
# 20         10240      13174109       6218260.00         13.17
# 21         11264      15877455       5675470.00         15.88
# 22         12288      20727287       4742730.00         20.73
# 23         13312      18011375       5912710.00         18.01
# 24         14336      18626465       6157260.00         18.63
# 25         15360      22435837       5476950.00         22.44
# 26         16384      50523767       2594260.00         50.52
# 27         17408      24842715       5605830.00         24.84
# 28         18432      62427092       2362050.00         62.43
# 29         19456      38408416       4052450.00         38.41
# 30         20480      30609176       5352640.00         30.61
# 31         21504      25760929       6678020.00         25.76
# 32         22528      35141957       5128460.00         35.14
# 33         23552      23234502       8109320.00         23.23
# 34         24576      35151365       5593180.00         35.15
# 35         25600      36189636       5659080.00         36.19
# 36         26624      33578274       6343150.00         33.58
# 37         27648      40047620       5523020.00         40.05
# 38         28672      31245446       7341100.00         31.25
# 39         29696      49187912       4829800.00         49.19
# 40         30720      31003257       7926910.00         31.00
# 41         31744      45573246       5572390.00         45.57
# 42         32768      52629794       4980900.00         52.63
#
#     Throughput (Mbps)  Filtered latency (ms)  Filtered throughput (Mbps)
# 0                0.00               5.790000                    0.000000
# 1                0.12               5.980000                    0.030000
# 2                0.23               6.200000                    0.080000
# 3                0.27               6.835000                    0.127500
# 4                0.37               7.273750                    0.188125
# 5                0.56               7.252813                    0.281094
# 6                0.66               7.259609                    0.375820
# 7                0.83               7.124707                    0.489365
# 8                0.99               6.966030                    0.614524
# 9                1.11               6.849523                    0.738393
# 10               1.10               6.949642                    0.828795
# 11               1.08               7.104732                    0.891596
# 12               1.31               8.446049                    0.996197
# 13               1.59              10.192036                    1.144648
# 14               3.97               9.706527                    1.850986
# 15               4.00               9.842396                    2.388239
# 16               1.86              13.971797                    2.256180
# 17               4.89              13.408847                    2.914635
# 18               5.00              13.334136                    3.435976
# 19               4.25              14.338102                    3.639482
# 20               6.22              14.046076                    4.284611
# 21               5.68              14.504557                    4.633459
# 22               4.74              16.060918                    4.660094
# 23               5.91              16.548188                    4.972570
# 24               6.16              17.068641                    5.269428
# 25               5.48              18.411481                    5.322071
# 26               2.59              26.438611                    4.639053
# 27               5.61              26.038958                    4.881790
# 28               2.36              35.136719                    4.251342
# 29               4.05              35.955039                    4.201007
# 30               5.35              34.618779                    4.488255
# 31               6.68              32.404084                    5.036191
# 32               5.13              33.088063                    5.059643
# 33               8.11              30.623547                    5.822233
# 34               5.59              31.755161                    5.764174
# 35               5.66              32.863870                    5.738131
# 36               6.34              33.042903                    5.888598
# 37               5.52              34.794677                    5.796449
# 38               7.34              33.908508                    6.182336
# 39               4.83              37.728881                    5.844252
# 40               7.93              36.046661                    6.365689
# 41               5.57              38.427495                    6.166767
# 42               4.98              41.978122                    5.870075

# %%
# Plot filter

rawValues = np.transpose(data.values);

figure2, axis2 = plt.subplots(2);
figure2.suptitle("Filtered Latency (Mbps) and throughput (ms)");
axis2[0].plot(rawValues[0], rawValues[5]);
axis2[1].plot(rawValues[0], rawValues[6]);
